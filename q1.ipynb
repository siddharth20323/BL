# %%
import hashlib

# %%
message="blockchain Developer"
msg_byte=message.encode()

# %%
sha_256_hash=hashlib.sha256(msg_byte)

# %%
digest=sha_256_hash.hexdigest()

# %%
print("Message",message)
print("SH-256 digest",digest)
# Out:
# Message blockchain Developer
# SH-256 digest f3b8709d5a4fc9f550d0393e32513ef260a1675a6ec7b41a3d99e8d0de047bad
